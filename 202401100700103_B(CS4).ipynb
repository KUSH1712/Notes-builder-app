# %%
# Simple To-Do Notes Builder App

todo_list = []

def show_menu():
    print("\n==== TO-DO LIST MENU ====")
    print("1. View tasks")
    print("2. Add task")
    print("3. Mark task as done")
    print("4. Delete task")
    print("5. Exit")

def view_tasks():
    if not todo_list:
        print("\nYour to-do list is empty.")
    else:
        print("\nYour Tasks:")
        for index, task in enumerate(todo_list):
            status = "ok" if task["done"] else "not ok"
            print(f"{index + 1}. {task['task']} [{status}]")

def add_task():
    task = input("Enter a new task: ")
    todo_list.append({"task": task, "done": False})
    print("Task added!")

def mark_done():
    view_tasks()
    try:
        task_no = int(input("Enter task number to mark as done: ")) - 1
        if 0 <= task_no < len(todo_list):
            todo_list[task_no]["done"] = True
            print("Task marked as done.")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Please enter a valid number.")

def delete_task():
    view_tasks()
    try:
        task_no = int(input("Enter task number to delete: ")) - 1
        if 0 <= task_no < len(todo_list):
            removed = todo_list.pop(task_no)
            print(f"Task '{removed['task']}' deleted.")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Please enter a valid number.")

# Main program loop
while True:
    show_menu()
    choice = input("Choose an option (1-5): ")

    if choice == '1':
        view_tasks()
    elif choice == '2':
        add_task()
    elif choice == '3':
        mark_done()
    elif choice == '4':
        delete_task()
    elif choice == '5':
        print("Goodbye!")
        break
    else:
        print("Invalid choice. Please enter a number from 1 to 5.")
# Out:
# ==== TO-DO LIST MENU ====
# 1. View tasks
# 2. Add task
# 3. Mark task as done
# 4. Delete task
# 5. Exit
# Choose an option (1-5): 1
#
# Your to-do list is empty.
#
# ==== TO-DO LIST MENU ====
# 1. View tasks
# 2. Add task
# 3. Mark task as done
# 4. Delete task
# 5. Exit
# Choose an option (1-5): 2
# Enter a new task: Doing python CA revision
# Task added!
#
# ==== TO-DO LIST MENU ====
# 1. View tasks
# 2. Add task
# 3. Mark task as done
# 4. Delete task
# 5. Exit
# Choose an option (1-5): 2
# Enter a new task: Going to picnic
# Task added!
#
# ==== TO-DO LIST MENU ====
# 1. View tasks
# 2. Add task
# 3. Mark task as done
# 4. Delete task
# 5. Exit
# Choose an option (1-5): 1
#
# Your Tasks:
# 1. Doing python CA revision [not ok]
# 2. Going to picnic [not ok]
#
# ==== TO-DO LIST MENU ====
# 1. View tasks
# 2. Add task
# 3. Mark task as done
# 4. Delete task
# 5. Exit
# Choose an option (1-5): 3
#
# Your Tasks:
# 1. Doing python CA revision [not ok]
# 2. Going to picnic [not ok]
# Enter task number to mark as done: 1
# Task marked as done.
#
# ==== TO-DO LIST MENU ====
# 1. View tasks
# 2. Add task
# 3. Mark task as done
# 4. Delete task
# 5. Exit
# Choose an option (1-5): 1
#
# Your Tasks:
# 1. Doing python CA revision [ok]
# 2. Going to picnic [not ok]
#
# ==== TO-DO LIST MENU ====
# 1. View tasks
# 2. Add task
# 3. Mark task as done
# 4. Delete task
# 5. Exit
# Choose an option (1-5): 4
#
# Your Tasks:
# 1. Doing python CA revision [ok]
# 2. Going to picnic [not ok]
# Enter task number to delete: 2
# Task 'Going to picnic' deleted.
#
# ==== TO-DO LIST MENU ====
# 1. View tasks
# 2. Add task
# 3. Mark task as done
# 4. Delete task
# 5. Exit
# Choose an option (1-5): 1
#
# Your Tasks:
# 1. Doing python CA revision [ok]
#
# ==== TO-DO LIST MENU ====
# 1. View tasks
# 2. Add task
# 3. Mark task as done
# 4. Delete task
# 5. Exit
# Choose an option (1-5): 5
# Goodbye!
